# %% [markdown]
# # Lógica de Programação

# %%
1 + 1
# Out:
# 2

# %%
"Guilherme"
# Out:
# 'Guilherme'

# %%
'Guilherme'
# Out:
# 'Guilherme'

# %%
nome = 'Guilherme'

# %%
nome
# Out:
# 'Guilherme'

# %%
idade = 28
