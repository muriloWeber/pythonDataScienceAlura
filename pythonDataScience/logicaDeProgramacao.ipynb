# %% [markdown]
# # Lógica de Programação

# %%
1 + 1
# Out:
# 2

# %%
"Guilherme"
# Out:
# 'Guilherme'

# %%
'Guilherme'
# Out:
# 'Guilherme'

# %%
nome = 'Guilherme'

# %%
nome
# Out:
# 'Guilherme'

# %%
idade = 28

# %%
print('O nome é Gulherme e sua idade é 28 anos')
# Out:
# O nome é Gulherme e sua idade é 28 anos

# %%
print(f'O nome é {nome} e sua idade é {idade} anos')
# Out:
# O nome é Guilherme e sua idade é 28 anos

# %%
idade = 29

# %%
print(f'O nome é {nome} e sua idade é {idade} anos')
# Out:
# O nome é Guilherme e sua idade é 29 anos

# %% [markdown]
# # Criando minha primeira função

# %%
def saudacao():
  nome = input('Qual o seu nome? ')
  print(f'Olá {nome}')

# %%
saudacao()
# Out:
# Qual o seu nome? Murilo
# Olá Murilo
